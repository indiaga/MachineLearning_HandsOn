# %%
# 라이브러리 로딩
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import display, HTML

sns.set()

display(HTML("<style>.container { width:100% !important; }</style>"))
#display(HTML(' <span style="color:red">the title is: <h1>Hello, world!</h1> </span>  '))

## 각 컬럼 width 최대로
pd.set_option('display.max_colwidth', -1)

# Use 3 decimal places in output display ex) {:,.0f}
pd.options.display.float_format = '{:,.0f}'.format

# Don't wrap repr(DataFrame) across additional lines
pd.set_option("display.expand_frame_repr", True)

# Set max rows displayed in output to 25
pd.set_option("display.max_rows", 60)
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# 데이터파일 정의
use_colidx = np.arange(3,114)
use_colnms = ['매출귀속부서','영업대표','PJT코드','PJT명','End_User','매출처','구분','확률','시작일','종료일','수주금액','외주원가','상품원가','경비','GP1',
                '취급액_1','매출_1','용역수익_1','상품매출_1','외주원가_1','상품원가_1','경비_1','GP1_1',
                '취급액_2','매출_2','용역수익_2','상품매출_2','외주원가_2','상품원가_2','경비_2','GP1_2',
                '취급액_3','매출_3','용역수익_3','상품매출_3','외주원가_3','상품원가_3','경비_3','GP1_3',
                '취급액_4','매출_4','용역수익_4','상품매출_4','외주원가_4','상품원가_4','경비_4','GP1_4',
                '취급액_5','매출_5','용역수익_5','상품매출_5','외주원가_5','상품원가_5','경비_5','GP1_5',
                '취급액_6','매출_6','용역수익_6','상품매출_6','외주원가_6','상품원가_6','경비_6','GP1_6',
                '취급액_7','매출_7','용역수익_7','상품매출_7','외주원가_7','상품원가_7','경비_7','GP1_7',
                '취급액_8','매출_8','용역수익_8','상품매출_8','외주원가_8','상품원가_8','경비_8','GP1_8',
                '취급액_9','매출_9','용역수익_9','상품매출_9','외주원가_9','상품원가_9','경비_9','GP1_9',
                '취급액_10','매출_10','용역수익_10','상품매출_10','외주원가_10','상품원가_10','경비_10','GP1_10',
                '취급액_11','매출_11','용역수익_11','상품매출_11','외주원가_11','상품원가_11','경비_11','GP1_11',
                '취급액_12','매출_12','용역수익_12','상품매출_12','외주원가_12','상품원가_12','경비_12','GP1_12']
col_type = {"매출귀속부서":str,"영업대표":str,"PJT명":str,"End_User":str,"매출처":str,"구분":str,"시작일":str,"종료일":str}

csv_prev = 'D:\\MyPython\\boss_forecast\\boss_forecast_202004_v1.csv'
csv_this = 'D:\\MyPython\\boss_forecast\\boss_forecast_202004_v2.csv'

result_filepath = 'D:\\MyPython\\boss_forecast\\'

# %%
# 데이터파일 가져오기
boss_prev = pd.read_csv(csv_prev,header=1, usecols=use_colidx, names=use_colnms, index_col=2, thousands=',', decimal ='.', encoding='euc-kr', skipfooter = 2, engine = 'python', dtype=col_type)
boss_prev['집계'] ='전차'
boss_prev.set_index('집계', append=True)
boss_this = pd.read_csv(csv_this,header=1, usecols=use_colidx, names=use_colnms, index_col=2, thousands=',', decimal ='.', encoding='euc-kr', skipfooter = 2, engine = 'python', dtype=col_type)
boss_this['집계'] ='당차'
boss_this.set_index('집계', append=True)
boss_sales = pd.concat([boss_prev,boss_this])
boss_sales.describe()
# Out:
#        확률          수주금액          외주원가        상품원가         경비         GP1  \
# count 419 419           419           419         419        419
# mean  78  127,591,339   15,475,419    80,358,814  650,443    31,106,664
# std   36  196,849,086   88,599,912    110,179,172 2,625,709  75,040,355
# min   0   0             0             0           0          -2,332,185
# 25%   50  12,421,800    0             0           0          1,280,000
# 50%   100 65,000,000    0             29,320,000  0          5,928,000
# 75%   100 153,443,550   0             123,551,500 0          20,000,000
# max   100 1,500,000,000 1,100,000,000 706,790,500 23,053,050 506,356,818
#
#        취급액_1        매출_1      용역수익_1      상품매출_1  ...   경비_11     GP1_11  \
# count 419    419         419         419          ... 419     419
# mean  0      4,884,035   3,574,434   1,309,601    ... 1,245   56,362
# std   0      26,876,952  24,734,657  10,024,398   ... 12,224  464,247
# min   0      -692,300    -692,300    0            ... 0       -1,007,950
# 25%   0      0           0           0            ... 0       0
# 50%   0      0           0           0            ... 0       0
# 75%   0      0           0           0            ... 0       0
# max   0      443,991,201 443,991,201 125,890,824  ... 141,710 6,124,393
#
#        취급액_12      매출_12   용역수익_12    상품매출_12   외주원가_12    상품원가_12   경비_12  \
# count 419     419        419       419        419       419        419
# mean  0       424,904    66,909    357,995    14,485    347,255    918
# std   0       5,181,923  339,028   5,175,462  116,370   5,020,198  11,371
# min   0       0          0         0          0         0          0
# 25%   0       0          0         0          0         0          0
# 50%   0       0          0         0          0         0          0
# 75%   0       0          0         0          0         0          0
# max   0       75,000,000 3,354,000 75,000,000 1,358,400 72,750,000 157,250
#
#          GP1_12
# count 419
# mean  62,245
# std   343,341
# min   0
# 25%   0
# 50%   0
# 75%   0
# max   3,283,652
#
# [8 rows x 102 columns]

# %%
# 팀분기합계 컬럼 생성
pd.options.display.float_format = '{:,.0f}'.format
boss_this_sum = boss_sales.groupby(['집계'])['매출_1','GP1_1','매출_2','GP1_2','매출_3','GP1_3','매출_4','GP1_4','매출_5','GP1_5','매출_6','GP1_6'].sum()/1000
boss_this_sum['매출_Q1'] = boss_this_sum['매출_1'] + boss_this_sum['매출_2'] + boss_this_sum['매출_3']  
boss_this_sum['GP1_Q1'] = boss_this_sum['GP1_1'] + boss_this_sum['GP1_2'] + boss_this_sum['GP1_3']  
boss_this_sum['매출_Q2'] = boss_this_sum['매출_4'] + boss_this_sum['매출_5'] + boss_this_sum['매출_6']  
boss_this_sum['GP1_Q2'] = boss_this_sum['GP1_4'] + boss_this_sum['GP1_5'] + boss_this_sum['GP1_6']  
boss_this_sum.loc[:,:]
format_dict = {'매출_1': '{:,.0f}', 'GP1_1': '{:,.0f}', '매출_2': '{:,.0f}', 'GP1_2': '{:,.0f}', '매출_3': '{:,.0f}', 'GP1_3': '{:,.0f}', '매출_4': '{:,.0f}', 'GP1_4': '{:,.0f}',
               '매출_5': '{:,.0f}', 'GP1_5': '{:,.0f}', '매출_6': '{:,.0f}', 'GP1_6': '{:,.0f}', '매출_Q1': '{:,.0f}', 'GP1_Q1': '{:,.0f}', '매출_Q2': '{:,.0f}', 'GP1_Q2': '{:,.0f}'}
boss_this_sum.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >매출_1</th>        <th class="col_heading level0 col1" >GP1_1</th>        <th class="col_heading level0 col2" >매출_2</th>        <th class="col_heading level0 col3" >GP1_2</th>        <th class="col_heading level0 col4" >매출_3</th>        <th class="col_heading level0 col5" >GP1_3</th>        <th class="col_heading level0 col6" >매출_4</th>        <th class="col_heading level0 col7" >GP1_4</th>        <th class="col_heading level0 col8" >매출_5</th>        <th class="col_heading level0 col9" >GP1_5</th>        <th class="col_heading level0 col10" >매출_6</th>        <th class="col_heading level0 col11" >GP1_6</th>        <th class="col_heading level0 col12" >매출_Q1</th>        <th class="col_heading level0 col13" >GP1_Q1</th>        <th class="col_heading level0 col14" >매출_Q2</th>        <th class="col_heading level0 col15" >GP1_Q2</th>    </tr>    <tr>        <th class="index_name level0" >집계</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11level0_row0" class="row_heading level0 row0" >당차</th>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col0" class="data row0 col0" >624,868</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col1" class="data row0 col1" >249,609</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col2" class="data row0 col2" >2,017,429</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col3" class="data row0 col3" >394,712</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col4" class="data row0 col4" >1,227,591</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col5" class="data row0 col5" >283,216</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col6" class="data row0 col6" >1,027,882</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col7" class="data row0 col7" >231,465</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col8" class="data row0 col8" >1,240,610</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col9" class="data row0 col9" >222,439</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col10" class="data row0 col10" >1,503,555</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col11" class="data row0 col11" >178,362</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col12" class="data row0 col12" >3,869,888</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col13" class="data row0 col13" >927,537</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col14" class="data row0 col14" >3,772,046</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row0_col15" class="data row0 col15" >632,265</td>
#             </tr>
#             <tr>
#                         <th id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11level0_row1" class="row_heading level0 row1" >전차</th>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col0" class="data row1 col0" >1,421,543</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col1" class="data row1 col1" >874,512</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col2" class="data row1 col2" >1,809,430</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col3" class="data row1 col3" >441,110</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col4" class="data row1 col4" >1,464,966</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col5" class="data row1 col5" >310,746</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col6" class="data row1 col6" >1,121,965</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col7" class="data row1 col7" >253,139</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col8" class="data row1 col8" >1,214,412</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col9" class="data row1 col9" >226,688</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col10" class="data row1 col10" >1,516,328</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col11" class="data row1 col11" >184,388</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col12" class="data row1 col12" >4,695,938</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col13" class="data row1 col13" >1,626,368</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col14" class="data row1 col14" >3,852,705</td>
#                         <td id="T_0d0788a2_7978_11ea_bbf2_00155d9beb11row1_col15" class="data row1 col15" >664,215</td>
#             </tr>
#     </tbody></table>

# %%
# 팀분기합계 컬럼 생성
boss_this_sum = boss_sales.groupby(['영업대표','집계'])['매출_1','GP1_1','매출_2','GP1_2','매출_3','GP1_3','매출_4','GP1_4','매출_5','GP1_5','매출_6','GP1_6'].sum()/1000
boss_this_sum['매출_Q1'] = boss_this_sum['매출_1'] + boss_this_sum['매출_2'] + boss_this_sum['매출_3']  
boss_this_sum['GP1_Q1'] = boss_this_sum['GP1_1'] + boss_this_sum['GP1_2'] + boss_this_sum['GP1_3']  
boss_this_sum['매출_Q2'] = boss_this_sum['매출_4'] + boss_this_sum['매출_5'] + boss_this_sum['매출_6']  
boss_this_sum['GP1_Q2'] = boss_this_sum['GP1_4'] + boss_this_sum['GP1_5'] + boss_this_sum['GP1_6']  
boss_this_sum.to_csv(result_filepath + 'boss_salesman.csv', encoding='euc-kr')
boss_this_sum

format_dict = {'매출_1': '{:,.0f}', 'GP1_1': '{:,.0f}', '매출_2': '{:,.0f}', 'GP1_2': '{:,.0f}', '매출_3': '{:,.0f}', 'GP1_3': '{:,.0f}', '매출_4': '{:,.0f}', 'GP1_4': '{:,.0f}',
               '매출_5': '{:,.0f}', 'GP1_5': '{:,.0f}', '매출_6': '{:,.0f}', 'GP1_6': '{:,.0f}', '매출_Q1': '{:,.0f}', 'GP1_Q1': '{:,.0f}', '매출_Q2': '{:,.0f}', 'GP1_Q2': '{:,.0f}'}
boss_this_sum.style.format(format_dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_1ae445ba_7978_11ea_8925_00155d9beb11" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >매출_1</th>        <th class="col_heading level0 col1" >GP1_1</th>        <th class="col_heading level0 col2" >매출_2</th>        <th class="col_heading level0 col3" >GP1_2</th>        <th class="col_heading level0 col4" >매출_3</th>        <th class="col_heading level0 col5" >GP1_3</th>        <th class="col_heading level0 col6" >매출_4</th>        <th class="col_heading level0 col7" >GP1_4</th>        <th class="col_heading level0 col8" >매출_5</th>        <th class="col_heading level0 col9" >GP1_5</th>        <th class="col_heading level0 col10" >매출_6</th>        <th class="col_heading level0 col11" >GP1_6</th>        <th class="col_heading level0 col12" >매출_Q1</th>        <th class="col_heading level0 col13" >GP1_Q1</th>        <th class="col_heading level0 col14" >매출_Q2</th>        <th class="col_heading level0 col15" >GP1_Q2</th>    </tr>    <tr>        <th class="index_name level0" >영업대표</th>        <th class="index_name level1" >집계</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1ae445ba_7978_11ea_8925_00155d9beb11level0_row0" class="row_heading level0 row0" rowspan=2>김민상</th>
#                         <th id="T_1ae445ba_7978_11ea_8925_00155d9beb11level1_row0" class="row_heading level1 row0" >당차</th>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col0" class="data row0 col0" >2,141</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col1" class="data row0 col1" >-300</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col2" class="data row0 col2" >303,838</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col3" class="data row0 col3" >61,635</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col4" class="data row0 col4" >77,141</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col5" class="data row0 col5" >9,699</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col6" class="data row0 col6" >2,214</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col7" class="data row0 col7" >-310</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col8" class="data row0 col8" >41,594</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col9" class="data row0 col9" >1,659</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col10" class="data row0 col10" >905,610</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col11" class="data row0 col11" >50,428</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col12" class="data row0 col12" >383,119</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col13" class="data row0 col13" >71,035</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col14" class="data row0 col14" >949,418</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row0_col15" class="data row0 col15" >51,776</td>
#             </tr>
#             <tr>
#                                 <th id="T_1ae445ba_7978_11ea_8925_00155d9beb11level1_row1" class="row_heading level1 row1" >전차</th>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col0" class="data row1 col0" >8,709</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col1" class="data row1 col1" >-483</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col2" class="data row1 col2" >303,838</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col3" class="data row1 col3" >61,447</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col4" class="data row1 col4" >77,141</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col5" class="data row1 col5" >9,521</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col6" class="data row1 col6" >2,214</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col7" class="data row1 col7" >-359</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col8" class="data row1 col8" >2,214</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col9" class="data row1 col9" >-359</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col10" class="data row1 col10" >905,610</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col11" class="data row1 col11" >50,380</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col12" class="data row1 col12" >389,687</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col13" class="data row1 col13" >70,485</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col14" class="data row1 col14" >910,038</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row1_col15" class="data row1 col15" >49,662</td>
#             </tr>
#             <tr>
#                         <th id="T_1ae445ba_7978_11ea_8925_00155d9beb11level0_row2" class="row_heading level0 row2" rowspan=2>김형중</th>
#                         <th id="T_1ae445ba_7978_11ea_8925_00155d9beb11level1_row2" class="row_heading level1 row2" >당차</th>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col0" class="data row2 col0" >31,243</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col1" class="data row2 col1" >27,401</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col2" class="data row2 col2" >253,103</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col3" class="data row2 col3" >36,757</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col4" class="data row2 col4" >671,841</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col5" class="data row2 col5" >52,973</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col6" class="data row2 col6" >160,620</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col7" class="data row2 col7" >2,894</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col8" class="data row2 col8" >531,995</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col9" class="data row2 col9" >11,258</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col10" class="data row2 col10" >247,582</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col11" class="data row2 col11" >12,494</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col12" class="data row2 col12" >956,187</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col13" class="data row2 col13" >117,131</td>
#                         <td id="T_1ae445ba_7978_11ea_8925_00155d9beb11row2_col14" class="data row2 col14" >940,196</td>
#                         <td i
